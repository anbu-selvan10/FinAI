# %%
# In[1]:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 import seaborn as sns
#       6 from statsmodels.tsa.arima.model import ARIMA
# ----> 7 from pmdarima import auto_arima
#       8 from sklearn.metrics import mean_squared_error
#       9 from sklearn.model_selection import TimeSeriesSplit
#
# ModuleNotFoundError: No module named 'pmdarima'

# %%
# %pip install pmdarima
# Out:
# ...
#   Using cached pmdarima-2.0.4.tar.gz (630 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pmdarima
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for pmdarima (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [43 lines of output]
#       Partial import of pmdarima during the build process.
#
#       Requirements: ['joblib>=0.11\nCython>=0.29,!=0.29.18,!=0.29.31\nnumpy>=1.21.2\npandas>=0.19\nscikit-learn>=0.22\nscipy>=1.3.2\nstatsmodels>=0.13.2\nurllib3\nsetuptools>=38.6.0,!=50.0.0\npackaging>=17.1  # Bundled with setuptools, but want to be explicit\n']
# ...

# %%
# !ls
# Out:
# arima2_model_Automotive.pkl  arima_model_Automotive.pkl  expenses.csv  sample_data

# %%
df = pd.read_csv(
    'expenses.csv',  # change to your actual file path
    usecols=['date', 'category', 'expense_amt_categorized']
)

# Parse the 'date' column (format is YYYY-MM-DD)
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

df = df.groupby(['date', 'category'], as_index=False)['expense_amt_categorized'].sum()

print(df.head())
print(df.shape)
# Out:
#         date           category  expense_amt_categorized
# 0 2024-10-23          Groceries                      486
# 1 2024-10-23              Other                     1215
# 2 2024-10-23            Savings                      458
# 3 2024-10-24  Gifts & Donations                     1308
# 4 2024-10-24       Petrol & Gas                      680
# (460, 3)

# %%
true_last_date = df['date'].max()

print("Last available date in the dataset:", true_last_date)
# Out:
# Last available date in the dataset: 2025-03-23 00:00:00

# %%
def rolling_forecast_validation(ts, initial_train_size=90, horizon=30):
    """Performs rolling forecast validation on time series data."""
    tscv = TimeSeriesSplit(n_splits=5)
    errors = []

    for train_idx, test_idx in tscv.split(ts):
        train, test = ts.iloc[train_idx], ts.iloc[test_idx]

        try:
            model = auto_arima(train, seasonal=True, stepwise=True, trace=False, suppress_warnings=True)
            order = model.order
            model = ARIMA(train, order=order).fit()
            forecast = model.forecast(steps=len(test))
            rmse = np.sqrt(mean_squared_error(test, forecast))
            errors.append(rmse)
        except Exception as e:
            print(f"ARIMA failed on validation fold. Reason: {e}")

    return np.mean(errors) if errors else None

# %%
monthly_expenses = df.resample('M', on='date').sum()["expense_amt_categorized"]

try:
    model_total = auto_arima(monthly_expenses, seasonal=True, stepwise=True, trace=False, suppress_warnings=True)
    order_total = model_total.order
    model_total = ARIMA(monthly_expenses, order=order_total).fit()

    future_months = pd.date_range(start=monthly_expenses.index[-1] + pd.DateOffset(months=1), periods=3, freq='M')
    total_forecast = model_total.get_forecast(steps=3)
    total_monthly_expenses = total_forecast.predicted_mean
except Exception as e:
    print(f"Failed to forecast total monthly expenses. Reason: {e}")
    total_monthly_expenses = None

# %%
all_categories = df["category"].unique()
forecasts_list = []
category_errors = {}

for cat in all_categories:
    df_cat = df[df["category"] == cat].copy()
    df_cat.set_index("date", inplace=True)
    df_cat = df_cat.resample("D").sum().fillna(0)  # Ensure daily data
    ts = df_cat["expense_amt_categorized"]

    try:
        rmse_score = rolling_forecast_validation(ts)
        category_errors[cat] = rmse_score

        model = auto_arima(ts, seasonal=True, stepwise=True, trace=False, suppress_warnings=True)
        order = model.order
        model = ARIMA(ts, order=order).fit()

        # ✅ Ensure forecast strictly starts from next day after `true_last_date`
        future_dates = pd.date_range(start=true_last_date + pd.Timedelta(days=1), periods=30, freq='D')
        forecast = model.get_forecast(steps=30)
        forecast_df = forecast.summary_frame()[["mean"]]
        forecast_df.rename(columns={"mean": "predicted_expense"}, inplace=True)

        # ✅ Cap predictions based on past maximum spending per category
        max_past_spending = ts.max()
        forecast_df["predicted_expense"] = np.minimum(forecast_df["predicted_expense"], max_past_spending)

        forecast_df["category"] = cat
        forecast_df["date"] = future_dates
        forecast_df = forecast_df[['date', 'predicted_expense', 'category']]
        forecasts_list.append(forecast_df)

    except Exception as e:
        print(f"ARIMA failed for category {cat}. Reason: {e}")

# %%
import pickle

with open(f"arima2_model_{cat}.pkl", "wb") as f:
    pickle.dump(model, f)

# %%
if forecasts_list:
    final_forecast = pd.concat(forecasts_list, ignore_index=True)

    # ✅ Ensure correct sorting
    final_forecast.sort_values(by=['date', 'category'], inplace=True)

    print("Next 30 Days Predicted Expenses by Category:")
    print(final_forecast)
else:
    print("No forecasts were generated.")
# Out:
# Next 30 Days Predicted Expenses by Category:
# expense_amt_categorized       date  predicted_expense               category
# 510                     2025-03-24         119.892980             Automotive
# 300                     2025-03-24         233.438849      Bills & Utilities
# 180                     2025-03-24         136.000014              Education
# 270                     2025-03-24         116.804535          Entertainment
# 420                     2025-03-24         121.154908           Food & Drink
# ..                             ...                ...                    ...
# 479                     2025-04-22         165.923716  Professional Services
# 239                     2025-04-22         177.546656                   Rent
# 89                      2025-04-22         133.841927                Savings
# 509                     2025-04-22         141.036752               Shopping
# 179                     2025-04-22         123.085783                 Travel
#
# ...

# %%
print(final_forecast.head())  # Check the start of the forecast
print(final_forecast.tail())  # Check the end of the forecast
# Out:
# expense_amt_categorized       date  predicted_expense           category
# 510                     2025-03-24         119.892980         Automotive
# 300                     2025-03-24         233.438849  Bills & Utilities
# 180                     2025-03-24         136.000014          Education
# 270                     2025-03-24         116.804535      Entertainment
# 420                     2025-03-24         121.154908       Food & Drink
# expense_amt_categorized       date  predicted_expense               category
# 479                     2025-04-22         165.923716  Professional Services
# 239                     2025-04-22         177.546656                   Rent
# 89                      2025-04-22         133.841927                Savings
# 509                     2025-04-22         141.036752               Shopping
# 179                     2025-04-22         123.085783                 Travel

# %%
# Group by category and sum predicted expenses
category_sums = final_forecast.groupby("category")["predicted_expense"].sum()

# Sort in descending order
category_sums_sorted = category_sums.sort_values(ascending=False)

print("\n📊 **Category-wise Total Predicted Expense for Next 30 Days (Descending Order):**")
print(category_sums_sorted)
# Out:
# 📊 **Category-wise Total Predicted Expense for Next 30 Days (Descending Order):**
# category
# Home                     5362.905621
# Groceries                5332.720286
# Rent                     5326.399672
# Miscellaneous            5187.689807
# Personal                 5168.293647
# Gifts & Donations        5061.063919
# Professional Services    4969.881584
# Shopping                 4231.102552
# Education                4080.000430
# Savings                  4015.257798
# Health & Wellness        4014.125417
# Bills & Utilities        3949.082011
# Petrol & Gas             3792.898566
# Food & Drink             3634.647243
# Automotive               3596.789399
# Travel                   3386.367311
# Entertainment            3368.992350
# Other                    3331.211431
# Name: predicted_expense, dtype: float64

# %%
total_predicted_expense = category_sums.sum()

print("\n💰 **Total Predicted Expense for Next 30 Days:**", total_predicted_expense)
# Out:
# 💰 **Total Predicted Expense for Next 30 Days:** 77809.4290432837

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("expenses.csv")

# Convert 'date' column to datetime format
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")

# Aggregate total expenses per category
category_expense = df.groupby("category")["expense_amt_categorized"].sum().reset_index()

# Sort categories by total expense
category_expense = category_expense.sort_values(by="expense_amt_categorized", ascending=False)

# Set plot style
sns.set_style("whitegrid")

# Bar plot: Total expenses per category
plt.figure(figsize=(12, 6))
sns.barplot(
    x="expense_amt_categorized",
    y="category",
    data=category_expense,
    palette="coolwarm"
)
plt.xlabel("Total Expense")
plt.ylabel("Category")
plt.title("Total Expenses Per Category")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("expenses.csv")

# Convert 'date' column to datetime format
df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")

# Extract year and month for grouping
df["year_month"] = df["date"].dt.to_period("M")

# Aggregate total expenses per month
monthly_expense = df.groupby("year_month")["expense_amt_categorized"].sum().reset_index()

# Convert 'year_month' to string for plotting
monthly_expense["year_month"] = monthly_expense["year_month"].astype(str)

# Set plot style
sns.set_style("whitegrid")

# Plot total expenses per month
plt.figure(figsize=(12, 6))
sns.barplot(
    x="year_month",
    y="expense_amt_categorized",
    data=monthly_expense,
    palette="viridis"
)
plt.xlabel("Month")
plt.ylabel("Total Expense")
plt.title("Total Spendings Per Month")
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Generate 18 distinct colors using seaborn color palette
unique_colors = sns.color_palette("tab20", n_colors=18)  # "tab20" provides 20 distinct colors

# Plot category-wise expenses over months with unique colors
ax = monthly_category_expense_actual.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6),
    color=unique_colors
)

plt.title("📊 Last 5 Months Category-wise Actual Expenses")
plt.xlabel("Month")
plt.ylabel("Total Expense")
plt.legend(title="Category", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.xticks(rotation=45)
plt.show()
